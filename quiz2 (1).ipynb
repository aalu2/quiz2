# %%
lst = ["a",3,4,"a",3]
def foo(lst):
  for a in lst:
    if(lst.count(a)==1):
      return a

foo(lst)
# Out:
# 4

# %%
lst2 = ["good","one","good","one",]
def foo(lst):
  for b in lst:
    if(lst2.count(b)==1):
      return b
      break
    else:
      print('None')

foo(lst2)
# Out:
# None
# None
# None
# None

# %%
lst = ["good"]
print(lst)
# Out:
# ['good']
